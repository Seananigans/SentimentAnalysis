# %%
import urllib2
from urllib2 import urlopen
import re
import cookielib
from cookielib import CookieJar
import datetime
import time
import nltk
from nltk import RegexpParser, word_tokenize, pos_tag, ne_chunk
import sqlite3

# %%
cj = CookieJar()
opener = urllib2.build_opener(urllib2.HTTPCookieProcessor(cj))
opener.addheaders = [("User-agent","Mozilla/5.0")]

# %%
def main():
    try:
        page = 'http://www.huffingtonpost.com/feeds/index.xml'
        source_code = opener.open(page).read()
        try:
            titles = re.findall(r"<title><!\[CDATA\[(.*?)]]></title>", source_code)
            for title in titles: 
                print title
            links = re.findall(r'<link>(.*?)</link>', source_code)
            for link in links: 
                time.sleep(1)
                print link
                if not link.startswith("http://"): link = 'http://'+link
                link_source = opener.open(link).read()
                content = re.findall(r"<p>((.|\n)*?)<p>Get top stories and blog posts emailed to me each day", link_source)
                for con in content: 
                    if "<img" in con: continue
                    if "<a href=" in con: continue
                    if "<div" in con: continue
                    if "</div>" in con: continue
                    if "href" in con: continue
                    if "</a>" in con: continue
                    if "<script" in con: continue
                        
                    print con
            return content
        except Exception, e:
            print str(e)
    except Exception, e:
        print str(e)

# %%
content = main()
# Out:
# This Bride And Her Bridesmaids Flawlessly Rocked Their Natural Hair
# Hip Hop and Vivaldi? Oh, Yes!
# For Belly Laughs, Hispanics Turn To 'El Chavo'
# Federal Judges Probe For 'Purposeful Discrimination' Behind North Carolina Voting Law
# The World We Live In As LGBT Travelers
# #The Project for Women (TPFW)
# Pope Francis Reminds Catholics Why Judging Others Isn't Christian
# Gay Advice. We Need to Talk... About Me
# Our Pluralistic Democracy Must Protect The Rainbow Children Of God
# Fitbit Says You’re Using Your Alarm Clock All Wrong
# Doin' Work, Flash Interviews With Contemporary Photographers: Ed Panar
# Beyond Divestment: Global Warming, Trauma And The Call For Pastoral Care
# 7 Things Polyamorous People Are Tired Of Hearing
# Brilliant Writers Describe The Dangers Of Donald Trump As Only They Can
# Biden Calls Out Trump In Speech Without Ever Mentioning His Name
# www.huffingtonpost.com
# http://www.huffingtonpost.com/2016/06/21/this-bride-and-her-bridesmaids-flawlessly-rocked-their-natural-hair_n_10602130.html
# ('Like many brides,&nbsp;Nakyia Whitty <a href="https://www.instagram.com/naturally_nakyia/" target="_blank">posted some photos</a> on Instagram after her June 11 wedding -- not thinking much of it at all.</p>\n<p>Among the snaps from the Punta Cana, Dominican Republic nuptials were some shots that featured her and her bridesmaids all rocking their natural hair.</p>\n</div></div>\n\n<figure class="content-list-component image">\n<img class="image__src" src="http://img.huffingtonpost.com/asset/scalefit_630_noupscale/57698a5a15000030001ba9bb.png?cache=gc62rgjupq" />\n<div class="image__credit js-image-credit">\n<a target="_blank" href="https://www.instagram.com/naturally_nakyia/">@naturally_nakyia\n</a></div>\n<figcaption class="image__caption js-image-caption">\n"All of my bridesmaids have natural hair as well. No one was against it at all."\n</figcaption>\n</figure>\n\n\n<div class="content-list-component text"><p>The following day, the Houston, Texas couple\'s phones were buzzing like crazy, as the pics quickly <a href="
# ('Sitcom is the most popular Spanish-language comedy in the U.S. and worldwide.</p></div>\n<p><a href="http://images.huffingtonpost.com/2016-06-18-1466251910-4749283-elchavo11.jpg"><img alt="2016-06-18-1466251910-4749283-elchavo11.jpg" src="http://images.huffingtonpost.com/2016-06-18-1466251910-4749283-elchavo11-thumb.jpg" width="570" height="301" /></a> </p>\n<div class="content-list-component mt-paragraph text"><p><em>This article is part of an ongoing Media Life series entitled "<a href="http://www.medialifemagazine.com/catching-the-next-big-wave-hispanic-media/" target="_hplink">Catching the next big wave: Hispanic media.</a>" You can read previous stories by clicking <a href="http://www.medialifemagazine.com/tag/catching-the-next-big-wave-hispanic-advertising/" target="_hplink">here</a>.</em></p></div>\n<div class="content-list-component mt-paragraph text"><p>In the courtyard of a housing project, an orphan squats next to the barrel where he sleeps at night. Wearing a green-checkered cap with flaps covering his ears, the boy daydreams about toys he\'ll never have. With a sigh, he pulls out an old-fashioned cup-and-ball -- made of stick, tin can and string -- and begins to play.</p></div>\n<div class="content-list-component mt-paragraph text"><p>Sad story? Actually, no.</p></div>\n<div class="content-list-component mt-paragraph text"><p>The scene is from "El chavo del ocho" ("The Kid from 8"), the most popular sitcom in U.S. Hispanic and Latin American television history and the top-ranked comedy in the Hispanic market today.</p></div>\n<div class="content-list-component mt-paragraph text"><p>If you want to understand fundamentals of Spanish-language TV-and just how different they are from English-language TV-look no further than "El chavo del ocho."</p></div>\n<div class="content-list-component mt-paragraph text"><p>"El chavo" is one quirky TV show.</p></div>\n<div class="content-list-component mt-paragraph text"><p>No one knows El chavo\'s name -- it\'s never once uttered.</p></div>\n<div class="content-list-component mt-paragraph text"><p>The title character, the young boy, is played by a middle-aged man, <a href="http://www.chespirito.com/" target="_hplink">Roberto G\xc3\xb3mez Bola\xc3\xb1os</a>, known to fans simply as Chesperito, a derivative of Shakespearito ("Little Shakespeare").</p></div>\n<div class="content-list-component mt-paragraph text"><p>Whenever the little boy gets scared, he becomes immobile, his left arm drooping, his right arm splayed outward. To be revived, he must be splashed in the face with cold water.</p></div>\n<div class="content-list-component mt-paragraph text"><p>But here\'s what\'s most interesting. There have been no new episodes of the sitcom since 1980. It debuted in 1971, and production stopped nine years later.</p></div>\n<div class="content-list-component mt-paragraph text"><p>Yet it\'s a true phenomenon, dubbed into more than 50 languages. Repeats of the show pull an estimated global audience of 91 million viewers daily.</p></div>\n<div class="content-list-component mt-paragraph text"><p>In the U.S., "El chavo" is everywhere. If you include episodes from an animated follow-up series, an astounding 31 shows air weekly among the combined Univisi\xc3\xb3n, UniM\xc3\xa1s and Galavisi\xc3\xb3n networks. Another 18 half hours of the variety show "Chesperito," which regularly feature "El chavo" skits until 1992, appear each week on Galavisi\xc3\xb3n\'s screen.</p></div>\n<div class="content-list-component mt-paragraph text"><p>But surprisingly the show is no ratings monster. Neither it -- nor any comedy -- regularly appears in the Spanish-language Nielsen top 20.</p></div>\n<div class="content-list-component mt-paragraph text"><p>Comedy plays a much smaller role in the U.S. Spanish-language TV market.</p></div>\n<div class="content-list-component mt-paragraph text"><p>When they want laughs, U.S. Latinos are more likely to turn to English TV, with shows such as "The Big Bang Theory" and "Mo ...
# http://www.huffingtonpost.com/2016/06/21/north-carolina-voting-discrimination_n_10601218.html
# ('Federal appeals court judges on Tuesday probed the intent behind a sweeping 2013 North Carolina law that changed the state\'s election rules.</p>\n<p>A lawyer for the state, Thomas Farr, defended the law and denied claims by attorneys for the U.S. Justice Department and civil rights groups that the law intentionally suppressed minority voters, speaking before the U.S. Court of Appeals for the Fourth Circuit in Richmond, Virginia.</p>\n<p>The court already temporarily stayed the law\'s provisions that eliminate voters\' ability to register the same day they vote and to vote outside their assigned precincts, methods that critics say are disproportionately used by minority voters.</p>\n<p>If the appeals court follows a lower court\'s April ruling and upholds the law, those options may not be available for North Carolina voters in the upcoming election in November, widely viewed as one of the most critical presidential and general elections in recent U.S. history.</p>\n<p>Judge Henry Floyd asked Farr about the fact that the legislature considered an expanded version of the law soon after the U.S. Supreme Court ruled in Shelby County v. Holder that Congress could no longer subject states with a record of race-based voter discrimination to special elections oversight.</p>\n<p>North Carolina\'s Republican-controlled legislature got the "opportunity" to change some "pretty liberal voter registration provisions" with that decision, Floyd said.</p>\n<p>"And it happened the same day Shelby was decided. Looks pretty bad to me, in terms of purposeful discrimination," he added.</p>\n<p>Judge James Wynn asked Farr what type of voter behavior information the state legislature considered when passing the law: "At the time that it enacted this, did it have ... information that the use of these particular procedures was disproportionately higher in the minority community than they were in the non-minority community?"</p>\n<p>Farr replied that the state board of elections launched a campaign to educate voters about the new requirements.</p>\n<p>"When these rules were used in 2014 election, African-American turnout increased at a higher rate than whites," Farr told Reuters by email after the hearing.</p>\n<p>Attorneys for the civil rights groups opposing the law appeared jubilant afterwards, greeting supporters outside the courthouse and at a local church in Richmond, where NAACP members sang, spoke and answered questions from reporters.</p>\n<p>"The judges asked really probing questions to understand the crux of the matter," said Allison Riggs, a lawyer for the Southern Coalition for Social Justice. "The court below just got the law wrong."</p></div>\n\n<script></script>\n<iframe style="display: none;"></iframe>\n\n\n\n<script class="article-bottom-ad-script-template" type="text/template">\n\n\n</script>\n\n\n\n<section class="extra-content">\n<h4 class="extra-content__title">Also on HuffPost</h4>\n<div class="extra-content__media">\n\n<div class="slideshow vertical" data-beacon=\'{"p":{"mnid":"slideshow","lnid":"open","dL_sDpt":"gallery"}}\' data-data-url="/mapi/v2/us/entry/us_5769c558e4b09926ce5cfbd0/slideshow/55c51b62e4b0f73b20b97c62.json?device=desktop" data-slideshow-id="55c51b62e4b0f73b20b97c62" id="slideshow-55c51b62e4b0f73b20b97c62" style="background-image:url(http://img.huffingtonpost.com/asset/scalefit_950_800_noupscale/55c51b4f1400002e002e25aa.jpeg);">\n<div class="slideshow__preview">\n<div class="slideshow__preview__icon"></div>\n<div class="slideshow__preview__text">\n<div class="slideshow__preview__text__title">Historic Images Of Women Voting</div>\n</div>\n</div>\n</div>\n<div class="slideshow-overlay hidden" data-beacon=\'{"p":{"mlid":"slideshow"}}\' id="overlay-55c51b62e4b0f73b20b97c62">\n<div class="slideshow-overlay__header">\n<div class="slideshow-overlay__header__hp"></div>\n<h2 class="slideshow-overlay__header__title">Historic Images Of Women Voting</h2>\n<div class="slideshow-overlay__header__close" data-beacon=\'{"p":{" ...
# http://www.huffingtonpost.com/dane-steele-green/trouble-in-paradise-now_b_10510144.html
# ('The sad thing -- the really sad thing -- about Orlando is that is probably going to get worse before it gets better. Guns laws, gun nuts, lone wolves, persistent homo- and transphobia, evangelical Islam\'s continued backslide into medievalism, evangelical Christianity\'s continued infiltration into politics; it all has combined (and will go on to) into a perfect storm where a religious wingnut can not only become armed to the teeth, but actually feel that the world is on their side.</p></div>\n<div class="content-list-component mt-paragraph text"><p>In 2012, I wrote a piece on where gays should not go. We in the West tend to forget that when it comes to being gay, the West is the exception. Being gay can get you killed in a lot of places, even ones billing themselves as a paradise. But now it is 2016, and there have been changes, both forward and backward.</p></div>\n<div class="content-list-component mt-paragraph text"><p>So as the summer travel season officially kicks off, here is a new summary of those places that you should really think twice about visiting. Yes, every country in the world has a thriving gay community, but being gay in New York City is very different from being gay in Cairo. As before, this summary is painted in brief, broad strokes based on national law (if you want specifics, head to the IGLTA website, or even the <a href="http://www.state.gov/travel/" target="_hplink">State Department</a>). It may be that not all of these laws are enforced, but the fact anti-gay legislation exists means LGBTQs need to plan ahead and, as galling as it is, modify their behavior and dress as needed.</p></div>\n<div class="content-list-component mt-paragraph text"><p><strong>Africa</strong><br />\nTo their credit, several countries, including Guinea-Bissau, Mauritius, Cape Verde, and Rwanda, legalized homosexuality even if other bans (same-sex unions, serving openly in the military, etc.) remain in place. Other countries, like Mali, Djibouti, and Burkina Faso, have no laws on the books one way or another. In both such places, however, cultural and religious prohibitions can still make things dangerous when it comes to PDAs, law or no law. Even more dangerous are Egypt and Morocco, which will imprison you; Malawi, which will imprison and whip you; and Mauritania, which will kill you outright.</p></div>\n<div class="content-list-component mt-paragraph text"><p>This is not to say there aren\'t a few victories: A major upturn is Mozambique, which in 2015 adopted a new legal code that that definitively defends same-sex behavior (it was ambiguous before). Workplace discrimination has been illegal since 2007, and the country is an undiscovered gem when it comes to destinations.</p></div>\n<div class="content-list-component mt-paragraph text"><p>But it is South Africa that remains the shining star. Cape Town, which recently hosted the <a href="https://www.iglta.org/" target="_hplink">IGLTA</a> Convention, is pulling out all the stops to become the gay capital of the Southern Hemisphere, and it is well worth the 17-hour flight. But even South Africa has its problems: A worsening economic and political situation means that the rainbow tapestry so beautifully woven by the late Nelson Mandela is now fraying at the edges. This is not translating into homophobia necessarily, but foreigners should be mindful of things like pickpocketing and mugging (which affects everybody). Stay in the "popular zones" and if it is late at night, take a taxi from wherever you are to your hotel, and vice versa.</p></div>\n<div class="content-list-component mt-paragraph text"><p><strong
harm to these our brothers and sisters, our children, the sacred children of God?&rdquo;</p></div>\n\n<script></script>\n<iframe style="display: none;"></iframe>\n\n\n\n<script class="article-bottom-ad-script-template" type="text/template">\n\n\n</script>\n\n\n\n<section class="extra-content">\n<h4 class="extra-content__title">Also on HuffPost</h4>\n<div class="extra-content__media">\n\n<div class="slideshow vertical" data-beacon=\'{"p":{"mnid":"slideshow","lnid":"open","dL_sDpt":"gallery"}}\' data-data-url="/mapi/v2/us/entry/us_5769981ee4b065534f48071f/slideshow/56e33010e4b065e2e3d5f5e3.json?device=desktop" data-slides ...
# http://www.huffingtonpost.com/jimmy-fowlie/gay-advice-we-need-to-tal_b_10574930.html
# ('On last week\'s episode of Go-Go Boy Interrupted, Danny received a debilitating blow to his ego when he embarrassed himself in front of his crush at LA Pride. Now, Danny rounds up his best friends to strategize what is the next right move and also to tweeze his eyebrows. Watch below:</p></div>\n<p><div class="flex-video-container" style="left: 0px; width: 100%; height: 0px; position: relative; padding-bottom: 56.2493%;"><div class="video-flip youtube" id="youtube-flip-4hiI2G6eU_Q" data-youtube-id="4hiI2G6eU_Q"></div></div></p>\n\n<script></script>\n<iframe style="display: none;"></iframe>\n\n\n\n<script class="article-bottom-ad-script-template" type="text/template">\n\n\n</script>\n\n\n\n<script></script>\n<iframe style="display: none;"></iframe>\n\n\n\n<div class="follow-author">\nFollow Jimmy Fowlie on Twitter:\n<a class="follow-author__link" href="http://www.twitter.com/JimmyFowlie" target="_blank">www.twitter.com/JimmyFowlie</a>\n</div>\n\n\n<div class="entry-corrections">\n<a class="suggest-correction" href="javascript:void(0)" id="suggest-correction-link"></a>\n</div>\n\n<div class="below-entry">\n<div class="below-entry__content">\n\n\n<div class="below-entry__comments">\n<a class="comment-button js-comment-button" data-beacon=\'{"p":{"mnid":"comments","lnid":"open"}}\' data-edition="us" data-headline="Gay Advice. We Need to Talk... About Me" data-id="10574930" data-timestamp-published-date="06/21/2016 06:54 pm ET" data-url="http://www.huffingtonpost.com/jimmy-fowlie/gay-advice-we-need-to-tal_b_10574930.html" href="">\nComments\n</a>\n\n</div>\n\n<div class="advertisement below_entry_recirc" data-beacon=\'{"p":{"mnid":"ad","lnid":"below_entry_recirc"}}\'>\n<div id=\'taboola-below-article-thumbnails\' class="taboola hp-entry-you_may_like"></div>\r\n<div id=\'hp-more-gravity\'></div>\r\n\r\n<script>\r\n(function(){\r\nvar c = document.getElementById(\'taboola-below-article-thumbnails\');\r\nc.id += \'-\' + Math.round(Math.random()*1e16);\r\nvar taboolaParams = {\r\n  loader: "http://cdn.taboola.com/libtrc/aol-huffingtonpost/loader.js",\r\n  mode: "thumbnails-a",\r\n  container: c.id,\r\n  placement: "Below Article Thumbnails",\r\n  target_type: "mix"\r\n};\r\n\r\nwindow.modulousQueue.add(function(){ doTaboola(taboolaParams); });\r\n\r\n}());\r\n</script>\n</div>\n\n\n\n\n</div>\n</div>\n\n\n\n<script class="mid-article-ad-script-template" type="text/template">\n\n\n</script>\n<script class="entry-paragraph-1-ad-script-template" type="text/template">\n\n\n</script>\n<script class="sharebox-ad-script-template" type="text/template">\n\n\n</script>\n<script class="mid-article-ad-script-template" type="text/template">\n\n\n</script>\n</div>\n<script>\n  MW.modules.smarten.selector(\'.js-entry\');\n</script>\n<div class="right-rail" data-beacon=\'{"p":{"mlid":"sidebar_right"}}\' id="js-right-rail">\n\n<div class="sticky__container">\n<div class="advertisement right_rail_flex sticky" data-beacon=\'{"p":{"mnid":"ad","lnid":"right_rail_flex"}}\'>\n<script type="text/javascript">\r\n  if ( "function" === typeof(adSetSyncDelay) ) {\r\n    adSetSyncDelay(\'125\');\r\n  }\r\n</script>\r\n<div id="ad_right_rail_flex" class="ad_wrapper_top"><div id="adtech_right_rail_flex"></div>\r\n<script>\r\nwindow.modulousQueue.add(function(){\r\n  \r\n    waitForGlobal(\'htmlAdWH\', function() {\r\n      var adsDiv = document.querySelector(\'#adtech_right_rail_flex\');\r\n      adsDiv.removeAttribute(\'id\');\r\n      adsDiv.reloadCount = 0;\r\n      var adId = \'93507336\';\r\n      try { adId = io_c3sd.ads["right_rail_flex"] || adId; } catch(e) {} \r\n      \r\n      \r\n      var args = [\'RR\', \'RR\'\r\n      ];\r\n      \r\n      \r\n\r\n      htmlAdWH(adId, args[0], args[1], \'f\', adsDiv);\r\n      if (typeof debugadcode == \'function\') { debugadcode(\'AdTech\', {placement: \'right_rail_flex\', mnid: adId}, adsDiv); }\r\n      \r\n      jQuery(document).on(\'reloadAd\', function(ev, elem) {\r\n        if (elem && !elem.contains(adsDiv))  ...
# http://www.huffingtonpost.com/brian-levin-jd/our-pluralistic-democracy_b_10601208.html
# ('<strong>Awash With Guns</strong></p></div>\n<div class="content-list-component mt-paragraph text"><p>Heavily-armed freelance terrorist killers -- inspired by foreign extremists groups but not orchestrated by them -- like the one who struck Orlando last week and my community six months ago, represent a critical ongoing terror threat to America, but not the only one. As I testified before Congress in October 2015: "The United States faces multiple severe risk factors and a diverse set of emerging contemporary actors" with the most prominent being violent salafist jihadists, followed by domestic far right anti-government or bigoted extremists, with many of the worst now being active shooters. </p></div>\n<div class="content-list-component mt-paragraph text"><p>Despite this, and a ruling yesterday by the Supreme Court not to overturn a Connecticut law restricting assault weapons, the Senate failed to move forward on four limited proposals involving access to firearms for those on terror watch lists. This availability of weaponry has not been lost on extremists.</p></div>\n<div class="content-list-component mt-paragraph text"><p>Adam Gadahn, the deceased spokesman for Al Qaeda, another group the killer supported, exclaimed in 2011:</p></div>\n<p><blockquote></p>\n<div class="content-list-component mt-paragraph text"><p>America is absolutely awash with easily obtainable firearms. You can go down to a gun show at the local convention center and come away with a fully automatic assault rifle, without a background check, and most likely without having to show an identification card. So what are you waiting for?</p></div>\n<p></blockquote></p>\n<div class="content-list-component mt-paragraph text"><p>Even the late Justice Antonin Scalia, a champion of Second Amendment rights in upholding a personal right to firearms ownership against a total handgun ban in the case of <a href="https://www.law.cornell.edu/supct/html/07-290.ZO.html" target="_hplink">D.C. v. Heller</a>, 554 U.S. 570 (2008) still ruled the government may impose reasonable restrictions: </p></div>\n<p><blockquote></p>\n<div class="content-list-component mt-paragraph text"><p>Like most rights, the right secured by the Second Amendment is not unlimited. From Blackstone through the 19th-century cases, commentators and courts routinely explained that the right was not a right to keep and carry any weapon whatsoever in any manner whatsoever and for whatever purpose..... [N]othing in our opinion should be taken to cast doubt on longstanding prohibitions on the possession of firearms by felons and the mentally ill, or laws forbidding the carrying of firearms in sensitive places such as schools and government buildings, or laws imposing conditions and qualifications on the commercial sale of arms.</p></div>\n<p></blockquote></p>\n<div class="content-list-component mt-paragraph text"><p><strong>Armed Freelance Terrorists Pose A Threat</strong></p></div>\n<div class="content-list-component mt-paragraph text"><p>As I wrote in the Huffington Post in 2010: "Lone wolf offenders in particular often self-radicalize from a volatile mix of personal distress, psychological issues, and an ideology that can be sculpted to justify and explain their anti-social leanings." Yet, despite red flags about the killer\'s behavior and instability from law enforcement, employers, and a gun store owner he was still able to buy a Sig Sauer MCX folding semi-automatic rifle used in the Orlando massacre. </p></div>\n<div class="content-list-component mt-paragraph text"><p>Not all unstable hate freelancers with access to guns are primarily homophobes or salafist jihadists either. Exactly one year ago, Dylan Roof murdered nine innocent African-American worshippers at Mother Emanuel church in Charleston, South Carolina despite having a criminal record that should have prevented a firearm purchase. These attacks lie at the intersection of hate crime -- where a crime target is intentionally selected due to perceiv ...
# http://www.huffingtonpost.com/2016/06/21/fitbit-alarm-clock-app_n_10601204.html
# ('Trouble shutting down at night and hitting the pillow? There&rsquo;s a Fitbit app for that.</p>\n<p>Fitbit, the maker of fitness-tracking devices, has rolled out new features for its <a href="https://www.fitbit.com/app" target="_blank">app</a> aimed at improving sleep. Among the updates are alerts to remind you to go to sleep, and a vibrating wakeup alarm that gently rouses you out of sleep without disturbing your partner.</p>\n<p>&ldquo;Establishing a consistent sleep schedule is one of the simplest and most powerful things you can do to improve sleep,&rdquo; Fitbit&rsquo;s Melanie Chase, director of product marketing, told The Huffington Post.</p>\n<p>And that&rsquo;s the goal of the new Sleep Schedule app, Chase said -- &ldquo;to help guide you to get a more consistent pattern of sleep.&rdquo;</p>\n<p>The new tools make personalized sleep recommendations. The app uses your previous sleep history to set setting optimal bedtimes and wakeup times. Users can get bedtime push notification reminders on their smartphones, and set silent alarms on their Fitbit devices based on personalized recommendations.</p>\n<p>Don&rsquo;t worry: You can override the recommendations to set alarms that match your schedule.</p>\n<p>Users can track sleep progress using the app\'s history charts.</p>\n<p>The updated app is compatible with all Fitbit devices that track sleep (and through manual sleep tracking with Fitbit One).</p>\n<h4>What about REM?</h4>\n<p>Noticeably absent from Fitbit&rsquo;s sleep-tracking offerings is the capability to monitor how deeply you sleep. Other sleep trackers (such as the <a href="https://jawbone.com/up">Jawbone UP</a> or the <a href="https://www.withings.com/fr/en/products/aura/sleep-sensor-accessory">Aura Sleep Sensor</a>) let users know how much time they spend in deep, light and REM sleep -- and therefore how well rested you should (theoretically) feel.</p>\n<p>Fitbit said the focus of its app update is to help users improve sleep consistency for better sleep quality.</p>\n<p>&ldquo;Getting enough sleep and regularly going to bed around the same time each night can be a challenge,&rdquo; Chase said. The app&rsquo;s new tools look at your data, analyze it for patterns and create a personalized sleep schedule for you.</p>\n<p>"This [app] is for people looking to make the most of their sleep and attempt to optimize the sleep that they are getting in order to maximize their daytime productivity,"&nbsp;Michael Grandner, director of the University of Arizona\'s sleep and health research program (and is a Fitbit sleep adviser), told HuffPost.</p>\n<h4>Can an app make you sleep better?</h4>\n<p>Science agrees that <a href="http://healthysleep.med.harvard.edu/healthy/getting/overcoming/tips">going to bed and waking up at the same time every day</a> is one of the best things you can do for your sleep. The consistency helps set your body&rsquo;s internal clock, so you expect to sleep at the same time every night and you actually sleep better because your body is ready for that sleep, according to experts.</p>\n<p>But you need to actually clock all the sleep you need to get the benefits, sleep expert and adviser <a href="http://www.elsvanderhelm.com/" target="_blank">Els van der Helm</a>, told HuffPost.</p>\n<p>Sleep trackers can overestimate the amount of time that was spent asleep, which could be dangerous if users are building up more sleep debt than they think, van der Helm said.</p></div>\n<blockquote class="content-list-component pull-quote">\n<span class="quote">Rely on your own best judgment of both your sleep and how you feel during the day -- subjectively.</span>\n<span class="attribution">Els van der Helm, sleep expert and adviser</span>\n</blockquote>\n\n<div class="content-list-component text"><p>One <a href="http://www.ncbi.nlm.nih.gov/pubmed/21971963">study</a> found that Fitbits misidentified sleep and wake times, compared with higher quality tests used by sleep doctors (like polysomnography and standard ac ...
# http://www.huffingtonpost.com/tara-wray/doin-work-flash-interview_8_b_10476098.html
# ('Welcome back to Doin\' Work: Flash Interviews With Contemporary Photographers. This is a place to celebrate the photographers who inspire me, and present you with an easily digestible bite of their personalities and work.</p></div>\n<div class="content-list-component mt-paragraph text"><p>This week\'s guest is <a href="http://www.edpanar.com/" target="_hplink">Ed Panar</a>. Panar was born in 1976 in Johnstown, Pennsylvania. He received a MFA from Cranbrook Academy of Art, and currently lives in Pittsburgh. His previous publications include, <em>Golden Palms</em> (J&L) and <em>Same Difference</em> (Gottlund Verlag) and <em>Nothing Changes if Nothing Changes</em>. Panar\'s newest book <em><a href="http://www.artbook.com/9780989785976.html" target="_hplink">Animals That Saw Me: Volume Two</a></em> (The Ice Plant) will be available in Fall 2016.  </p></div>\n<p><a href="http://images.huffingtonpost.com/2016-06-15-1465987813-8681991-01__EdPanaronHalloween1980.jpg"><img alt="2016-06-15-1465987813-8681991-01__EdPanaronHalloween1980.jpg" src="http://images.huffingtonpost.com/2016-06-15-1465987813-8681991-01__EdPanaronHalloween1980-thumb.jpg" width="459" height="570" /></a></p>\n<div class="content-list-component mt-paragraph text"><p>Ed Panar, Halloween 1980, image courtesy the artist</p></div>\n<div class="content-list-component mt-paragraph text"><p><strong>Where do you live and work and how does it inform your photography?</strong></p></div>\n<div class="content-list-component mt-paragraph text"><p>My work is always informed by where I live at the moment, and most of my projects begin with the exploration of my everyday surroundings. Now I live in Pittsburgh where I enjoy wandering its hilly terrain and hidden neighborhoods.</p></div>\n<div class="content-list-component mt-paragraph text"><p><strong
guardian</a>&nbsp;last week. "This day in Sacramento presented a different picture, of a thousand or so regular people who thought it was pretty cool how Trump showed up in a plane with his name on it. How naughty it was when he called the president \'stupid.\'"</p>\n<p>"Americans who have voted for Trump in the primaries have done so not because they agree with all, or any, of his statements or promises, but because he is an entertainment," Eggers continued. "He is a loud, captivating distraction and a very good comedian ... The moment he ceases to entertain &ndash; to say crazy shit &ndash; he will evaporate."</p>\n<p><span style="font-weight: 400;">Garrison Keillor described Trump in a <a href="http://www.sltrib.com/opinion/4005202-155/keillor-the-punk-who-would-be" target="_blank">widely syndicated essay</a>&nbsp;last week as "</span><span style="font-weight: 400;">the C-minus guy who sat behind you in history and poked you with his pencil and smirked when you asked him to stop." The "Prairie Home Companion" creator said Trump doesn\'t have any kind of philosophy, "just an attitude."</span></p>\n<p>Pointing to Trump\'s self-congratulatory tweets after a gunman killed 49 people at a gay nightclub, Keillor doubted that Republicans could teach Trump any humility.</p>\n<p>"The dreamers in the Republican Party imagine that success will steady him and he will come into the gravitational field of rea ...
# http://www.huffingtonpost.com/2016/06/21/joe-biden-donald-trump-speech_n_10600854.html

# %%
example = ["The \"Disaster\" Disaster",
"The 10 Craziest Moments From 'Game Of Thrones: Battle Of The Bastards'",
"When it comes to the veepstakes, be smart--not bold",
"LeBron James Unanimously Wins The NBA Finals MVP He So Clearly Deserves",
"Technology Tips to Help Bring Balance to the Lives of Working Mothers",
"Everything You Need To Know About The Outragious Impeachment Of Brazil's First Female President",
"LeBron James Finally Won The City Of Cleveland Its Championship",
"My Multiracial Identity Isn't A Party Trick Or A Hookup Goal",
"When Father's Day Isn't Enough",
"An Open Letter To The Dad Who Chose Me",
"A Different Kind Of Out",
"The Complications of Extra Dads on Father's Day",
"Exes Who Won't Let Go After Divorce",
"To Prevent Sexual Violence In Conflict, We Have To Understand It First",
"NBA Game 7 Score"]

# %%
def process_content():
    try:
        for item in example:
            tokenized = nltk.word_tokenize(item)
            tagged = nltk.pos_tag(tokenized)
            
            named_ent = ne_chunk(tagged, binary=True)
            named_ent.draw()
            chunk_gram = r"""
            Chunk: 
            {<RB\w?>*<VB\w?>*<NNP>}
            }<RB|NNS>{
            """
            chunk_parser = nltk.RegexpParser(chunk_gram)
            
            chunked = chunk_parser.parse(tagged)
            print chunked
            print named_ent
    except Exception, e:
        print str(e)

# %%
process_content()

# %%
conn = sqlite3.connect("knowledgeBase.db")
c = conn.cursor()

visited_links = []

# %%
# Execute once to create a table
# c.execute("CREATE TABLE knowledgeBase (unix REAL, datestamp TEXT, namedEntity TEXT, relatedWord TEXT)")
# Executed

# %%
def processor(data):
    try:
        tokenized = word_tokenize(data)
        tagged = pos_tag(tokenized)
        named_ent = ne_chunk(tagged, binary=True)
        entities = re.findall(r"NE\s(.*?)/",str(named_ent))
        descriptives = re.findall(r"\(\'(\w*)\',\s\'JJ\w?\'",str(tagged))
        if len(entities)>1:pass
        elif len(entities)==0:pass
        else:
            print "__"*30
            print "Named: {}".format(entities[0])
            print "Descriptives: "
            for desc in descriptives:
                print desc
                current_time = time.time()
                datestamp = datetime.datetime.fromtimestamp(current_time).strftime("%Y-%m-%d %H:%M:%S")
                named_ent = entities[0]
                c.execute("INSERT INTO knowledgeBase (unix, datestamp, namedEntity, relatedWord) VALUES (?, ?, ?, ?)",
                         (current_time, datestamp, named_ent, desc))
                conn.commit()
    except Exception, e:
        print str(e)

# %%
def huffingtonRSSvisit():
    try:
        page = "http://www.huffingtonpost.com/feeds/index.xml"
        source_code = opener.open(page).read()
        try:
            links = re.findall("<link>(.*?)</link>", source_code)
            visited_links = [lk[0] for lk in c.execute("SELECT * FROM visited_links")]
            for link in links:
                if link in set(visited_links):
                    print "Link already visited."
                    continue
                c.execute("INSERT INTO visited_links (link) VALUES (?)",(link,))
                conn.commit()
                time.sleep(1)
                print "Visiting Page."
                print "#"*50
                if link.startswith("www"): continue
                link_source = opener.open(link).read()
                lines_of_interest = re.findall("<p>(.*?)</p>", str(link_source))
                print "CONTENT"
                for line in lines_of_interest:
                    if "<img width" in line: pass
                    if "<a href=" in line: pass
                    processor(line)
        except Exception, e:
            print "Failed main loop, inner"
            print str(e)
    except Exception, e:
        print "Failed main loop"
        print str(e)

# %%
huffingtonRSSvisit()
# Out:
# Link already visited.
# Visiting Page.
# ##################################################
# CONTENT
# ____________________________________________________________
# Named: California
# Descriptives:
# last
# close
# historic
# sixth
# balanced
# unresolved
# broad
# legislative
# unfinished
# unresolved
# homelessness
# ____________________________________________________________
# Named: Local
# Descriptives:
# Local
# municipal
# homeless
# much
# other
# ____________________________________________________________
# Named: Los
# Descriptives:
# intense
# public
# real
# first
# homelessness
# public
# open
# ____________________________________________________________
# Named: California
# Descriptives:
# statewide
# great
# broad
# various
# public
# private
# rational
# sustainable
# most
# human
# ____________________________________________________________
# Named: Get
# Descriptives:
# top
# personalized
# Visiting Page.
# ##################################################
# CONTENT
# ____________________________________________________________
# Named: Tesla
# Descriptives:
# best
# electric
# key
# green
# fossil
# ____________________________________________________________
# Named: Musk
# Descriptives:
# automotive
# sustainable
# ____________________________________________________________
# Named: Powerwall
# Descriptives:
# last
# same
# excess
# solar
# ____________________________________________________________
# Named: Nevada
# Descriptives:
# s
# biggest
# full
# next
# few
# new
# flexible
# more
# entire
# last
# ____________________________________________________________
# Named: Rive
# Descriptives:
# solar
# better
# standby
# instant
# ____________________________________________________________
# Named: Rive
# Descriptives:
# most
# excited
# residential
# ____________________________________________________________
# Named: Tesla
# Descriptives:
# long
# humble
# s
# ____________________________________________________________
# Named: Get
# Descriptives:
# top
# personalized
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.
# Link already visited.

# %%
conn = sqlite3.connect("knowledgeBase.db")
conn.text_factory = str
c = conn.cursor()

word_used = "Drone"
query = "SELECT * FROM knowledgeBase WHERE namedEntity=?"

for row in c.execute(query, [(word_used)]):
    print row
# Out:
# (1466553180.173594, '2016-06-21 19:53:00', 'Drone', 'strong')
# (1466553180.175007, '2016-06-21 19:53:00', 'Drone', 'illegal')
# (1466553180.177977, '2016-06-21 19:53:00', 'Drone', 'local')
# (1466553180.179198, '2016-06-21 19:53:00', 'Drone', 'em')
# (1466555290.024417, '2016-06-21 20:28:10', 'Drone', 'strong')
# (1466555290.026725, '2016-06-21 20:28:10', 'Drone', 'illegal')
# (1466555290.028219, '2016-06-21 20:28:10', 'Drone', 'local')
# (1466555290.031723, '2016-06-21 20:28:10', 'Drone', 'em')

# %%
conn = sqlite3.connect("knowledgeBase.db")

c = conn.cursor()

def create_word_valueDB(table_name):
    c.execute("SELECT name FROM sqlite_master WHERE type='table';")
    table_names = [str(a[0]) for a in c.fetchall()]
    print table_names
    if not (table_name in set(table_names)):
        c.execute("CREATE TABLE {} (word TEXT, value REAL)".format(table_name))
        table_names.append(table_name)
    else:
        print "Table already in database."

# %%
create_word_valueDB("wordVals")
# Out:
# ['knowledgeBase', 'wordVals', 'visited_links']
# Table already in database.

# %%
starting_word = "bad"
starting_word_val = -1.0


query = "SELECT * FROM synonyms_complete WHERE word=?"
c.execute(query, [(starting_word)])
data = c.fetchone()
if data is None:
    print "Let's add \"{}\" to our database.".format(starting_word)
    c.execute("INSERT INTO synonyms_complete (word) VALUES (?)", (starting_word,))
    conn.commit()
else:
    print "Word \"{}\" already here.".format(starting_word)


def main():
    try:
        page = "http://www.thesaurus.com/browse/"+starting_word+"?s=t"
        source_code = opener.open(page).read()
        try:
            synonym_source_split = source_code.split("<div class=\"synonyms-horizontal-divider\"></div>")
            x = 0
            while x<len(synonym_source_split):
                try:
                    time.sleep(1)
                    synonym_split = synonym_source_split[x].split("</span></td>")[0]
                    synonym_split = synonym_split.split("class=\"synonym-description\">")
                    if len(synonym_split)>0:
                        synonym_split = synonym_split[1]
                    else:
                        synonym_split = synonym_split[0]
                    synoNyms = re.findall(r"class\=\"text\">(.*?)</span>", synonym_split)
                    for syn in synoNyms:
                        query = "SELECT * FROM wordVals WHERE word=?"
                        c.execute(query, [(syn)])
                        data = c.fetchone()
                        if data is None:
                            print "Let's add \"{}\" to our database.".format(syn)
                            c.execute("INSERT INTO wordVals (word, value) VALUES (?,?)", (syn, starting_word_val))
                            conn.commit()
                        else: 
                            print "Word \"{}\" already here.".format(syn)
                except Exception, e:
                    print "Failed in 3rd try\n"+str(e)
                x += 1
    
        except Exception, e:
            print "Failed in 2nd try\n"+str(e)
            
    except Exception, e:
        print "Failed in 1st try\n"+str(e)
# Out:
# Word "bad" already here.

# %%
main()
# Out:
# Word "poor" already here.
# Word "dreadful" already here.
# Word "atrocious" already here.
# Word "cheap" already here.
# Word "unacceptable" already here.
# Word "sad" already here.
# Word "lousy" already here.
# Word "crummy" already here.
# Word "awful" already here.
# Word "rough" already here.
# Word "synthetic" already here.
# Word "gross" already here.
# Word "imperfect" already here.
# Word "bummer" already here.
# Word "garbage" already here.
# Word "blah" already here.
# Word "diddly" already here.
# Word "inferior" already here.
# Word "downer" already here.
# Word "abominable" already here.
# Word "amiss" already here.
# Word "bad news" already here.
# Word "beastly" already here.
# Word "careless" already here.
# Word "cheesy" already here.
# Word "crappy" already here.
# Word "defective" already here.
# Word "deficient" already here.
# Word "dissatisfactory" already here.
# Word "erroneous" already here.
# Word "fallacious" already here.
# Word "faulty" already here.
# Word "grungy" already here.
# Word "icky" already here.
# Word "inadequate" already here.
# Word "incorrect" already here.
# Word "off" already here.
# Word "raunchy" already here.
# Word "slipshod" already here.
# Word "stinking" already here.
# Word "substandard" already here.
# Word "unsatisfactory" already here.
# Word "junky" already here.
# Word "bottom out" already here.
# Word "cruddy" already here.
# Word "godawful" already here.
# Word "grody" already here.
# Word "not good" already here.
# Word "the pits" already here.
# Word "dangerous" already here.
# Word "unhealthy" already here.
# Word "damaging" already here.
# Word "deleterious" already here.
# Word "detrimental" already here.
# Word "hurtful" already here.
# Word "injurious" already here.
# Word "ruinous" already here.
# Word "wrong" already here.
# Word "evil" already here.
# Word "criminal" already here.
# Word "reprobate" already here.
# Word "base" already here.
# Word "delinquent" already here.
# Word "mean" already here.
# Word "corrupt" already here.
# Word "iniquitous" already here.
# Word "sinful" already here.
# Word "vicious" already here.
# Word "vile" already here.
# Word "villainous" already here.
# Word "wicked" already here.
# Word "wrong" already here.
# Word "disobedient" already here.
# Word "naughty" already here.
# Word "unruly" already here.
# Word "ill-behaved" already here.
# Word "misbehaving" already here.
# Word "rotten" already here.
# Word "sour" already here.
# Word "moldy" already here.
# Word "off" already here.
# Word "putrid" already here.
# Word "rancid" already here.
# Word "spoiled" already here.
# Word "distressing" already here.
# Word "harsh" already here.
# Word "terrible" already here.
# Word "disastrous" already here.
# Word "serious" already here.
# Word "intense" already here.
# Word "painful" already here.
# Word "grave" already here.
# Word "ill" already here.
# Word "ailing" already here.
# Word "diseased" already here.
# Word "unwell" already here.
# Word "in pain" already here.
# Word "sad" already here.
# Word "down" already here.
# Word "downcast" already here.
# Word "upset" already here.
# Word "low" already here.
# Word "regretful" already here.
# Word "apologetic" already here.
# Word "conscience-stricken" already here.
# Word "contrite" already here.
# Word "crestfallen" already here.
# Word "dejected" already here.
# Word "depressed" already here.
# Word "disconsolate" already here.
# Word "downhearted" already here.
# Word "guilty" already here.
# Word "remorseful" already here.
# Word "woebegone" already here.
# Word "unfavorable" already here.
# Word "unpleasant" already here.
# Word "grim" already here.
# Word "unfortunate" already here.
# Word "melancholy" already here.
# Word "adverse" already here.
# Word "disagreeable" already here.
# Word "discouraged" already here.
# Word "discouraging" already here.
# Word "distressed" already here.
# Word "gloomy" already here.
# Word "troubled" already here.
# Word "unhappy" already here.
# Word "displeasing" already here.
# Word "troubling" already here.
# Failed in 3rd try
# list index out of range

# %%
c.execute("CREATE TABLE synonyms_complete (word TEXT)")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-108-0a792f0d59f5> in <module>()
# ----> 1 c.execute("CREATE TABLE synonyms_complete (word TEXT)")
#
# OperationalError: table synonyms_complete already exists

# %%
for row in c.execute("SELECT COUNT(*) FROM wordvals"): print row
# Out:
# (375,)
